# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("This is Raghvendra")
# Out:
# This is Raghvendra

# %%
n = 5 # You can change the value of n here
result = n + n
print(f"The result of n + n is: {result}")
# Out:
# The result of n + n is: 10
